# %%
import glob
import pickle
import pandas as pd

# %%
all_args = []
all_args_ind = []
for filename in glob.glob('*.txt'):
    print(filename)
    with open(filename) as f:
        content = f.readlines()
        #print(content)
        #print()
        all_args_ind.append(content[:-1])
        all_args.extend(content)
# Out:
# no_effect40.txt
# no_effect16.txt
# no_effect30.txt
# no_effect43.txt
# no_effect4.txt
# no_effect3.txt
# no_effect29.txt
# no_effect18.txt
# no_effect34.txt
# no_effect44.txt
# no_effect41.txt
# no_effect9.txt
# no_effect13.txt
# no_effect35.txt
# neutral_positive_7.txt
# negative_positive_1.txt
# no_effect47.txt
# neutral_positive_3.txt
# no_effect37.txt
# negative_neutral_1.txt
# neutral_positive_4.txt
# neutral_positive_9.txt
# no_effect38.txt
# no_effect46.txt
# no_effect36.txt
# no_effect12.txt
# no_effect5.txt
# no_effect2.txt
# negative_neutral_2.txt
# Neutral_positive_1.txt
# no_effect39.txt
# neutral_positive_2.txt
# no_effect42.txt
# no_effect24.txt
# no_effect19.txt
# no_effect11.txt
# no_effect45.txt
# no_effect20.txt
# no_effect27.txt
# no_effect33.txt
# no_effect7.txt
# neutral_positive_5.txt
# no_effect10.txt
# no_effect28.txt
# no_effect17.txt
# no_effect23.txt
# neutral_positive_6.txt
# no_effect22.txt
# no_effect26.txt
# no_effect8.txt
# no_effect25.txt
# ...

# %%
all_moves = 0
for g in all_args_ind:
    all_moves += len(g)
    if len(g) > 10:
        for n in g:
            print(n)
    print()
# Out:
# User: I am young and healthy and also never get the flu vaccine
#
# CB: young_1
#
# User: but the same is true for the flu - I am sure if you are young and healthy the chances are less likely to get long covid
#
# CB: young_2
#
# User: the chances are still very low, so I don't think a vaccine is necessary
#
# CB: default_1
#
# User: that is very true
#
# CB: default_2
#
# User: also true, but I have to admit, I believe those that cannot get it or are at risk should be locked up and not the whole population
#
# CB: default_3
#
# User: I am not worried about it anyway
#
# CB: short_term_1
#
#
#
# User: It has been made too quickly and barely been tested
#
# CB: fast_dev_1
#
# User: Ok great but there are still definitely other solutions instead of getting the vaccine. There are a lot of other medicines that doctors have said could be used to treat it
#
# CB: default_1
#
# User: Technically not as there is a new variant now
#
# CB: mutation_1
#
# ...

# %%
all_args
# Out:
# ['User: I don’t ant it because it may not be safe yet and I don’t feel it has been tested enough. Or as much as other vaccines have. They took years To develop so why wouldn’t the others\n',
#  'CB: safety_1\n',
#  'User: I think even if the data was collected and was very transparent I think they could wait a bit longer. This is because what most people are worried about is the long-term defects on the wider population around the world people think it’s going to be like thalidomide \n',
#  'CB: default_1\n',
#  'User: This is why most people wouldn’t that mean most people are wondering like me why all the countries have two cases and why we have thousands of cases and we are worried that we are being convinced to take a vaccination but has not been fully tested and we are being rushed into it to control us\n',
#  'CB: default_2\n',
# ...

# %%
user_args_con= []
for g in all_args:
    if g[0] == 'U' and len(g.split()) > 2:
        user_args_con.append(g[6:])

# %%
user_len = 0
for arg in user_args_con:
    user_len += len(arg.split())

# %%
print(len(user_args_con))
print(user_len/353)
# Out:
# 353
# 15.575070821529746

# %%
bot_args_con= []
for g in all_args:
    if g[0] == 'C':
        bot_args_con.append(g[3:].strip())

# %%
print(len(bot_args_con))

Counter(bot_args_con).most_common()
# Out:
# 318
# [('default_1', 60),
#  ('default_2', 59),
#  ('default_3', 59),
#  ('long_term_1', 23),
#  ('short_term_1', 20),
#  ('safety_1', 14),
#  ('young_1', 13),
#  ('get_covid_1', 12),
#  ('fast_dev_1', 9),
#  ('death_1', 9),
#  ('long_term_2', 9),
#  ('mutation_1', 6),
#  ('flu_1', 5),
#  ('long_term_3', 4),
#  ('survival_rate_1', 4),
#  ('young_2', 3),
#  ('fertility_1', 2),
#  ('had_covid_1', 1),
#  ('mutation_2', 1),
#  ('short_term_2', 1),
#  ('fast_dev_2', 1),
#  ('young_3', 1),
#  ('safety_2', 1),
#  ('safety_3', 1)]

# %%
df_ua_con = pd.DataFrame(user_args_con)

# %%
df_ua_con.to_csv('all_args_iter_3.csv')

# %%
all_args
# Out:
# ['User: because it has been developed and rolled out so fast\n',
#  'CB: fast_dev_1\n',
#  'User: I understand that but we do not know long term side effects. you cannot buy time\n',
#  'CB: long_term_1\n',
#  "User: that might be true but I'd rather wait\n",
#  'CB: default_1\n',
#  'User: that is true, although pribably still some time away\n',
#  'CB: default_2\n',
#  'User: but there will be new variants\n',
#  'CB: mutation_1\n',
#  'User: there have been news about a variant where the vaccine doesnt work\n',
#  'CB: mutation_2\n',
#  'User: I will have to look into that\n',
#  'CB: default_3\n',
#  'User: true\n',
#  'User: Dont think enough research has been done yet\n',
#  'CB: default_1\n',
#  'User: Yeah i agree\n',
#  'CB: default_2\n',
#  'User: No,i think our bodies can fight off the virus\n',
#  'CB: default_3\n',
#  'User: You can still get virus with vaccine\n',
#  'User: I can still pass on COVID to someone else\n',
#  'CB: get_covid_1\n',
# ...

# %%
len(no_counter)
# Out:
# 462

# %%
all_args = all_args + logs_1 + logs_2
no_counter_args = []

counter_i = 0

defaults = ['default_1', 'default_2', 'default_3']

for arg in all_args:
    #print(log)
    arg = arg.split()
    if arg[-1] in defaults:

        no_counter_args.append(all_args[counter_i-1][5:])
    #print(counter_i)
    counter_i+=1

# %%
no_counter_args

no_counter = []

for a in no_counter_args:
    a_s = a.split()
    if len(a_s) > 2:
        no_counter.append(a)

# %%
for arg in no_counter:
    if len(arg.split()) < 20:
        print(arg)
        print()
# Out:
#  that might be true but I'd rather wait
#
#
#  that is true, although pribably still some time away
#
#
#  I will have to look into that
#
#
#  Dont think enough research has been done yet
#
#
#  Yeah i agree
#
#
#  No,i think our bodies can fight off the virus
#
#
#  I can get very sick from the vaccine
#
#
#  There are too many vaccines
#
#
#  the new strains
#
#
#  could be alergic
#
#
#  That doesnt affect me as i fully work from home and enjoy doing so
#
#
#  No confidence in government or the overstretched NHS
#
#
#  Scientists say restrictions will be in place for years though
#
#
#  I don’t feel like I need one
#
#
#  People should get vaccinated who need it and that will reduce cases
#
#
#  I'm unsure if I'll be allowed the vaccine due to a medical condition.
#
#
#  True, but I think we should still be cautious and not rush to go back to normality too soon.
#
#
#  Because no vaccine created before 5 years before
#
#
#  I don’t believe this
#
#
# ...

# %%
all_no_counter_args = ''.join(no_counter)

# %%
import re
from nltk import word_tokenize

from nltk.stem import WordNetLemmatizer, PorterStemmer, SnowballStemmer
stop_words_file = "/home/lisanka/final_study_COVID_vaccine/covid19_bot/SmartStoplist.txt"

stop_words = []

with open(stop_words_file, "r") as f:
    for line in f:
        stop_words.extend(line.split()) 
        
stop_words = stop_words  +  ['vaccine', 'people', 'covid', 'virus', 'vaccinated', 'vaccinate', 'vaccination','vaccines']

def preprocess(raw_text):
    
    #regular expression keeping only letters 
    letters_only_text = re.sub("[^a-zA-Z]", " ", raw_text)

    # convert to lower case and split into words -> convert string into list ( 'hello world' -> ['hello', 'world'])
    words = word_tokenize(letters_only_text.lower())

    cleaned_words = []
    lemmatizer = PorterStemmer() #plug in here any other stemmer or lemmatiser you want to try out
    
    # remove stopwords
    for word in words:
        if word not in stop_words:
            cleaned_words.append(word)
    
    # stemm or lemmatise words
    stemmed_words = []
    for word in cleaned_words:
        word = lemmatizer.stem(word)   #dont forget to change stem to lemmatize if you are using a lemmatizer
        stemmed_words.append(word)
    
    # converting list back to string
    return " ".join(stemmed_words)

# %%
all_no_counter_args_prep = preprocess(all_no_counter_args)

# %%
preprocess("what if vaccine doesnt work")
# Out:
# 'work'

# %%
from collections import Counter
Counter(all_no_counter_args_prep.split()).most_common(50)
# Out:
# [('immun', 40),
#  ('risk', 23),
#  ('effect', 23),
#  ('work', 22),
#  ('herd', 21),
#  ('year', 20),
#  ('like', 18),
#  ('develop', 18),
#  ('normal', 17),
#  ('bodi', 16),
#  ('trust', 16),
#  ('ve', 15),
#  ('back', 14),
#  ('true', 13),
#  ('time', 13),
#  ('affect', 13),
#  ('govern', 12),
#  ('protect', 12),
#  ('take', 12),
#  ('die', 12),
#  ('stop', 11),
#  ('agre', 10),
#  ('good', 10),
#  ('health', 10),
#  ('doesn', 10),
#  ('won', 10),
#  ('life', 10),
#  ('creat', 9),
#  ('test', 9),
#  ('medic', 9),
#  ('spread', 9),
#  ('achiev', 9),
#  ('side', 9),
#  ('surviv', 8),
#  ('rate', 8),
#  ('thing', 8),
#  ('lot', 8),
#  ('variant', 8),
#  ('catch', 8),
#  ('case', 7),
#  ('reason', 7),
#  ('put', 7),
#  ('futur', 7),
#  ('concern', 7),
#  ('worri', 7),
#  ('trial', 7),
#  ('bad', 7),
#  ('problem', 7),
#  ('data', 7),
#  ('complet', 7)]

# %%
words = ['immun', 'risk', 'effect', 'work', 'herd', 'govern', 'bodi', 'die', 'spread', 'variant' ]

# %%
from nltk.util import ngrams
n_gram = 2
n_gram_dic = dict(Counter(ngrams(all_no_counter_args.split(), n_gram)))

for i in n_gram_dic:
    if n_gram_dic[i] >= 4:
        print(i, n_gram_dic[i])
# Out:
# ('might', 'be') 5
# ('that', 'is') 11
# ('I', 'will') 9
# ('have', 'to') 8
# ('has', 'been') 15
# ('the', 'virus') 10
# ('from', 'the') 7
# ('the', 'vaccine') 66
# ('There', 'are') 7
# ('the', 'new') 4
# ('could', 'be') 8
# ('i', 'am') 4
# ('am', 'not') 12
# ('will', 'be') 9
# ('to', 'make') 4
# ('from', 'getting') 5
# ('I', 'don’t') 17
# ('I', 'need') 6
# ('should', 'get') 5
# ('get', 'vaccinated') 4
# ('it', 'and') 4
# ('Yes', 'but') 5
# ('covid', '19') 5
# ('a', 'vaccine') 15
# ('so', 'I') 4
# ('I', "don't") 17
# ("don't", 'know') 6
# ('if', 'I') 7
# ('it', 'is') 19
# ('that', 'I') 8
# ('there', 'are') 6
# ('in', 'the') 21
# ('we', 'are') 6
# ('a', 'lot') 7
# ('lot', 'of') 6
# ('vaccine', 'has') 7
# ('for', 'me') 6
# ('trust', 'the') 4
# ('to', 'take') 11
# ('I', 'am') 27
# ('not', 'just') 4
# ('that', 'it') 4
# ('about', 'the') 14
# ('it', 'was') 4
# ('it', 'to') 4
# ('to', 'the') 12
# ('for', 'people') 4
# ('people', 'that') 4
# ('there', 'is') 5
# ('is', 'no') 4
# ...

# %%
logs_1 = ['User: I am worried about the side effects',
 'CB: short_term_1',
 'User: I have a compromised immune system',
 'CB: young_1',
 'User: I have autoimmune conditions',
 'CB: default_1',
 'User: Because there is no date set for a return to normal life',
 'CB: safety_1',
 'User: Clinical trials have not been taken with people with my health conditions',
 'CB: default_2',
 'User: Prove to me that I will be safe with a vaccine',
 'CB: safety_2',
 'User: I am on immunosuppressants',
 'CB: default_3',
 'User: What total rubbish',
 'User: I am concerned about its reliability',
 'CB: default_1',
 'User: Yes but that is an "if", meaning that it is not the only possible outcome. There could be negative outcomes',
 'CB: short_term_1',
 'User: But what if I experience an unexpected side effect',
 'CB: short_term_2',
 'User: The vaccine may not be effective for me',
 'CB: default_2',
 'User: I could be a person with an allergy to the vaccine that occurs after taking it',
 'CB: default_3',
 'User: That could cause me to come careless with my health by assuming immunity. I may not be successful in immunity',
 "User: I am an anti-vaxxer in general. My son didn't have any of the childhood vaccines, I took the homoeopathic route instead.",
 'CB: default_1',
 'User: I believe that COVID 19 will die out in much the same way as the Spanish Flu.',
 'CB: flu_1',
 "User: I didn't compare it to the flu.",
 'CB: flu_2',
 "User: That's one of my worries - there is so much we don't know about the vaccine - efficacy, long-term side effects and how often the vaccine is needed.",
 'CB: long_term_1',
 "User: No one can say that the long term effects of the vaccine are less than COVID as it hasn't been tested enough.",
 'CB: long_term_2',
 "User: Vaccines that were given in the past shouldn't really be taken in to account - people live better now. We have clean water, good nutrition and housing.",
 'CB: default_2',
 'User: Because we are all (scientists, government the medical profession) dealing with something we know so little about.',
 'CB: default_3',
 "User: I would worry more about my health and my family's health if we had it.",
 'User: because others deserve it more',
 'CB: default_1',
 'User: only if the vaccine works',
 'CB: default_2',
 'User: i might be allergic to vaccine',
 'CB: default_3',
 "User: i'd worry if it made me ill",
 'CB: fast_dev_1',
 'User: might get covid from the vaccine',
 "User: Current jabs don't stop people getting or transmitting the virus, but people are not getting that message. If they think they are immune, they will go back to normal life and the spread will make 2020 look like a stroll in the park.",
 'CB: default_1',
 "User: It doesn't provide immunity.",
 'CB: default_2',
 "User: The current treatments are just that - treatments. They aren't vaccines, they don't provide immunity and they won't stop the spread. They will accellerate it.",
 'CB: default_3',
 "User: A packet of cough sweets doesn't stop people getting flu, it only helps with the symptoms. These so-called vaccines are no different.",
 'User: The MRNA vaccine technology is new and there is relatively little information on the long-term effects.',
 'CB: long_term_1',
 'User: Problems from COVID-19 are likely for people with other health problems. It is not correct to suppose that averaging the effects of COVID-19 on anyone who was sick will directly apply to any one individual.',
 'CB: short_term_1',
 "User: Not everyone experiences COVID-19 symptoms to the same degree. It's possible that some people will not have severe unpleasant side-effects, especially if they are healthy.",
 'CB: short_term_2',
 "User: Side-effects from COVID-19 arise from the body's immune system response which means that the immune system works and is doing its job.",
 'CB: young_1',
 'User: We have only known about covid for a year. We do not have enough experience or knowledge to be able to make any long-term claims.',
 'CB: long_term_2',
 'User: You have made an anti-vaccination argument to argue for the COVID-19 vaccine.',
 'CB: fast_dev_1',
 'User: You are not responding to my arguments.',
 'CB: default_1',
 'User: This is an appeal to emotion.',
 'CB: default_2',
 'User: There are many ways to create herd immunity. The healthy people who are not at risk for severe COVID-19 symptoms can generate antibodies naturally.',
 'CB: young_2',
 'User: I am not suggesting that we can assume all young and healthy people will be safe from COVID, but I could make the same argument for vaccines. There have been cases of people, both young and healthy, taking the COVID-19 vaccine and dying. And we do not know the reason for this.',
 'CB: young_3',
 'User: The vaccine has not been proven to prevent covid or covid transmission. It has only been shown to reduce symptoms in those who are exposed.',
 'CB: default_3',
 'User: I would still worry because I do not know the long-term effects of the vaccine or if they will make me susceptible to some other issue.',
 'CB: long_term_3',
 'User: That is a statement of conjecture. There is no way to know if the long term side-effects are more likely than the long term side effects from the vaccine because not enough time has passed in order to make any long-term comparisons.',
 'CB: long_term_4',
 'User: mRNA is a new technology. There is no long history with this type of vaccine.',
 'User: I have strong immunity',
 'CB: default_1',
 'User: we can still live life with no vaccine like we did before',
 'CB: default_2',
 'User: I dont believe their is prove that this vaccine will stop the spread of the virus, so too much of contradictions ',
 'CB: mutation_1',
 'User: but their is no evidence neither that it works',
 'CB: default_3',
 "User: I don't worry about my health like you assume ",
 'CB: young_1',
 'User: how about the effects of the vaccine it self ',
 'CB: short_term_1',
 'User: people are dying from the vaccine ',
 'User: Because there’s not enough data on how it will affect fertility ',
 'CB: default_1',
 'User: Having children is important to me',
 'CB: default_2',
 'User: If there turns out that the vaccine makes people infertile then there will be bigger problems to worry about',
 'CB: short_term_1',
 'User: That’s got nothing to do with what I said',
 'CB: default_3',
 'User: That is a dangerous lie to tell. You can’t use a blanket statement like that as it’s not a cure all',
 'User: I don’t know what’s in it ',
 'CB: default_1',
 'User: But the vaccine wasn’t designed for the new strain of coronavirus  ',
 'CB: default_2',
 'User: The vaccine had caused people I know to have side affects such as seizures',
 'CB: short_term_1',
 'User: Some of the side affects aren’t temporary though',
 'CB: short_term_2',
 'User: The government themselves are unsure weather the vaccine will work',
 'CB: default_3',
 'User: I have already had coronavirus so why would I get a jab protecting me from it ',
 'User: I do not think it is necessary for me to take the vaccine.',
 'CB: default_1',
 'User: That is not true. I can go back to normal life right now, in fact, I already have.',
 'CB: default_2',
 'User: Even if it is the ONLY safe way to create herd immunity against COVID-19, based off the data that we have about COVID-19, the vast majority of people only get mild symptoms and recover. Effectively doing the same thing as the vaccine.',
 'CB: default_3',
 'User: That is not true. Even if I got the vaccine, I would still have to do other things such as eat healthy  and exercise among other things to stay healthy.',
 'CB: young_1',
 "User: As does every other virus on earth. We don't vaccinate for chicken pox, yet almost everyone gets it and could potentially get shingles. ",
 'CB: mutation_1',
 "User: (this chatbot sucks at arguing because the responses aren't addressing what I'm saying).. Whether the vaccine works or not, I do not want to get it because I do not think it is necessary for me as a young and healthy individual to get the vaccine.",
 'CB: young_2',
 "User: (I take back what I said lol) There are always exceptions to the rule. Here in Canada it's something like 90% of the people dying from COVID-19 are above the age of 70. That's saying a lot considering that the majority of people getting sick are under 70. Children are seemingly off the radar of this virus as well. It's really just a spicy flu, and people who want the vaccine should feel empowered to get it and those that don't want it, shouldn't have to or be shamed for not doing it.",
 'User: Ok',
 'CB: default_1',
 'User: Ok',
 'CB: default_2',
 'User: Ok',
 'CB: default_3',
 'User: What if I die',
 "User: well you see just because we know the short-term side effects we don't know the long-term side effects",
 'CB: long_term_1',
 "User: just because we know the ingredients doesn't make it any less possible to have adverse long-term side effects",
 'CB: long_term_2',
 "User: then how was it made if it wasn't made using the actual active component of COVID-19. There are already mutations to the original virus! let me guess the vaccine protects me from those too!",
 'CB: default_1',
 "User: i don't have friends nor do i go out that's invalid the vaccine could be poison",
 'CB: default_2',
 'User: herd immunity, i feel like this is population control which is the complete opposite. what if a side-effect would cause sterility and infertility',
 'CB: short_term_1',
 "User: usually, so what you're saying is they haven't been as vigorous in testing this vaccine as they should be and therefore i shouldn't get the vaccine.",
 'CB: safety_1',
 "User: they don't care if things were skipped, they don't care if we live or die. They get paid regardless.",
 'CB: default_3',
 "User: assuming that i even have a family that is, which i don't. the people i care about are no longer present and this virus is going to do it's job and eliminate more of the world population. it's not a bad thing all things considered",
 'User: I’m not sure whether they’re safe to have',
 'CB: safety_1',
 'User: It seems too quick',
 'CB: fast_dev_1',
 'User: I fear safety had been compromised for speed',
 'CB: safety_2',
 'User: I understand all that, but there is no way of knowing any long term side effects',
 'CB: long_term_1',
 'User: It seems risky to have a vaccine which could lead to bigger problems down the line',
 'CB: default_1',
 'User: Until another variant arrives, then we’ll all be told we need another vaccine!!',
 'CB: mutation_1',
 'User: I would rather take my chances and not get vaccinated straight away, at least until a few months have passed',
 'CB: default_2',
 'User: Humanity has survived far worse pandemics in the past without the need for a vaccine',
 'CB: default_3',
 'User: COVID has a huge survival rate without vaccines anyway!',
 'User: Because of theories',
 'CB: default_1',
 'User: Ye ',
 'CB: default_2',
 'User: Yes',
 'CB: default_3',
 'User: Because the vaccine might not last long',
 'CB: long_term_1',
 'User: ok',
 'User: I do not feel that it has been tested for a long enough time frame to be sure it works',
 'CB: long_term_1',
 'User: I have already had Covid twice and survived so how can you know the side effects are not worse than the virus',
 'CB: short_term_1',
 'User: How do you know there aren’t long term side effects',
 'CB: long_term_2',
 'User: You say a very long time ago, Covid has only been around for a year ?',
 'CB: long_term_3',
 'User: They say that about flu but I don’t get the flu jab either so why would I get the Covid vaccine',
 'CB: flu_1',
 'User: But not all Covid survivors have long terms effects do they',
 'CB: long_term_4',
 'User: I feel the information on Covid survivors needs to be looked at more before we can weigh up whether everybody needs a vaccine',
 'CB: default_1',
 'User: They don’t know that it creates hers immunity though that hasn’t been tested ',
 'CB: safety_1',
 'User: I’ve read that even when you’ve had the vaccine you can still spread Covid you just don’t suffer the illness',
 'CB: default_2',
 'User: What if we all got vaccinated and a new variant developed that was resistant, do we then keep having more vaccines ',
 'CB: default_3',
 'User: I disagree as it’s still not been proven that vaccinated people can’t spread the disease',
 'END',
 'User: Quit',
 'User: There is not enough research on whether it affects fertility ',
 'CB: default_1',
 'User: yes but if it affects fertility how will more people create families?',
 'CB: default_2',
 'User: But is there enough evidence to prove it will not make people ill especially with most individuals having a 99.9% survivor rate when getting coronavirus?',
 'CB: default_3',
 'User: You may still have to worry about your health as it has taken less than a year to approve this vaccine',
 'User: cos its fast',
 'CB: default_1',
 'User: maybe',
 'CB: default_2',
 'User: k',
 'CB: default_3',
 'User: k',
 'User: Because it does not 100% prevent me from catching covid',
 'CB: default_1',
 'User: Heard immunity isn’t complete immunity ',
 'CB: default_2',
 'User: I do not think it is deemed safe yet',
 'CB: safety_1',
 'User: There is no efficient data to say how reliable it is',
 'CB: default_3',
 'User: I would rather it have actual proven results',
 'User: Worried about side effects',
 'CB: short_term_1',
 'User: The chance of me catching COVID is low',
 'CB: young_1',
 "User: the vaccine wasn't tested long enough, what about long term side effects?",
 'CB: long_term_1',
 "User: They've made a mess of the handling of COVID and I don't trust them with the vaccinr",
 'CB: fast_dev_1',
 "User: why can't i wait a year and then get it later when we know the side effects?",
 'CB: short_term_2',
 'User: quit',
 'END',
 'User: quit',
 "User: It's hasn't been tested long enought.",
 'CB: long_term_1',
 "User: I think we still need more evidence that vacine doesn't have significant side effects.",
 'CB: short_term_1',
 "User: I would like to have a baby and I'm worried the vacinr will negative effect on my unborn child. ",
 'CB: short_term_2',
 "User: I'm not worried about short term effects.",
 'CB: default_1',
 'User: Quit',
 'User: because it is essentially injecting the virus into your body',
 'CB: mutation_1',
 'User: i agree, you dont know what will happen',
 'CB: default_1',
 'User: that is what everyone wnats',
 'CB: default_2',
 'User: i dont agree that that is the answer',
 'CB: default_3',
 'User: because the vaccine was produced too quickly',
 'CB: fast_dev_1',
 'User: i just dont believe it will work. and not everyone will get it',
 "User: I have had numerous bad injections to jabs beforehand that have caused permanent damage to me. The doctors then completely denied the serious reactions that I had and I was completely medically neglected. I have also been repeatedly lied to by medical professionals over the last 3 decades. I have a lot of complex medical problems too, so don't know how my body will react to the vaccine.",
 'CB: default_1',
 "User: I will never be able to have a normal life because I am seriously ill, completely medically neglected and because the NHS are useless and completely corrupt. My life will also be made a lot worse if my body has a bad reaction to the jab... So no, we can't all go back to normal.",
 'CB: default_2',
 'User: But is the vaccine safe for me? You state that it is safe without knowing any of my medical history.',
 'CB: safety_1',
 'User: I am pretty sure they did not test the vaccine on people with my health problems. Also lots of other medicines have been declared safe by the medical industry, to be later found out that they are not. This has personally happened to me. The medical industry always try to cover up when this happens and never take responsibility.',
 'CB: safety_2',
 "User: You can't test something thoroughly and know all possible reactions/consequences in less than a year. Some peoples bodies react differently.",
 'CB: default_3',
 "User: Are you stupid? Of course I will have to worry about my health. I have progressive health problems. I have been getting sicker and sicker for the last 35 years. I suffer with hundreds of symptoms. I suffer immensely every single day. The vaccine won't fix my health, so why on earth would you say that I will no longer have to worry about my health if I get the vaccine.",
 'User: It has had mixed reviews and is too new on the market to trust',
 'CB: default_1',
 'User: I get that but there must be risks for some people',
 'CB: default_2',
 "User: Well, I read it hasn't been tested on pregnant women",
 'CB: safety_1',
 "User: It doesn't say anything about pregnant women though",
 'CB: default_3',
 "User: I don't know enough about it to convince anyone to take it",
 'User: As it won’t make me immune to having covid',
 'CB: young_1',
 'User: I’ve already contracted covid and developed immunity to it.',
 'CB: default_1',
 'User: I have considered this, but since many people have contracted it and would’ve gained immunity from it',
 'CB: default_2',
 'User: There are more harmful and detrimental illnesses which cause more deaths and more hospitalisation than covid, but these extreme measures are not taken',
 'CB: default_3',
 'User: You haven’t answered my argument',
 "User: Hasn't been throuroughly tested",
 'CB: safety_1',
 'User: not all demographics were a part of the clinical trials',
 'CB: default_1',
 'User: then allow the herd immunity to protect me',
 'CB: default_2',
 'User: i may have an allergy to the vaccine',
 'CB: default_3',
 'User: i believe people should be allowed to choose for themselves',
 "User: I don't trust that it is safe just yet.",
 'CB: safety_1',
 'User: The vaccines have not been out long enough yet to see the long term effects.',
 'CB: long_term_1',
 'User: Some people have been dieing from the vaccine.',
 'CB: default_1',
 'User: I agree, however I  think the vaccine needs more time.',
 'CB: default_2',
 'User: I agree with herd immunity but if the vaccine causes long term side effects and everyone gets vaccinated we will have a much serious problem on our hands.',
 'CB: long_term_2',
 "User: A long time ago doesn't matter. We know nothing about this slickness.",
 'CB: long_term_3',
 'User: Because we have no long term testing of the covid vaccine.',
 'CB: long_term_4',
 'User: When more time goes by I  might consider the vaccine if others have favorable results ',
 'CB: default_3',
 'User: The vaccine may not have long lasting coverage ',
 'END',
 'User: Quit',
 "User: I don't even get flu vaccines, and people have been dying after taking the vaccine",
 'CB: flu_1',
 'User: ok?',
 'CB: default_1',
 'User: cool story',
 'CB: default_2',
 "User: are you guys building a bot to change people's minds?",
 'CB: default_3',
 'User: this is so weird',
 'User: Because vaccines take years to develop and test and this somehow is ready in less than a year',
 'CB: default_1',
 "User: It still doesn't protest you from getting corona virus. It just make it milder",
 'CB: default_2',
 "User: If everybody in each country would be just locked up for 2 weeks.. Like with advanced warning so people could buy things for those 2 weeks and be prepared... Virus probably wouldn't survive.. ",
 'CB: default_3',
 "User: Covid is not the only thing in the world. Flu is more deadly than covid. Just covid is new. I mean covid 19. Covid in itself is around for many years already. So no, it wouldn't stop me from worrying. It would make me worried to look out for things after you get vaccine.. Like side effects.. The ones they surely couldn't have have testē enough ",
 'User: Why would i even want too, do we really know what is in it or if it even protects you against catching it....no ',
 'CB: default_1',
 'User: Its been like this for a year now a vaccine is not going to miraculously solve the issue when a full lock down should have been actioned completely ',
 'CB: default_2',
 'User: To stop it from spreading actaully close the country down apart from essential shops and businesses, yet manufacturing and construction are still open, i dont believe that this will stop us from catching it ',
 'CB: default_3',
 'User: 5d67bc65aa0252001bb1a8fc',
 'END',
 'User: Quit',
 'User: I’ve had Covid already and didn’t have any symptoms',
 'CB: default_1',
 'User: The vaccine doesn’t make you immune',
 'CB: default_2',
 'User: The vaccine doesn’t stop you spreading it',
 'CB: default_3',
 'User: I had Covid already',
 'User: scared of needles',
 'CB: default_1',
 'User: but im terrified of needles m8',
 'CB: default_2',
 'User: you havent addressed my concern',
 'CB: default_3',
 'User: i dont want to relive the trauma of needles thats what worries me',
 'User: I am worried about the potential side-effects.',
 'CB: short_term_1',
 "User: That is another reason I don't want to, because of the expedited process to get the vaccine out as quick as possible and lack of proper testing. I don't trust it.",
 'CB: default_1',
 'User: I believe that herd immunity can be achieved without myself getting the vaccine and the potential negative risks that come along with it.',
 'CB: default_2',
 'User: Most people will get the vaccine so herd immunity will still be achievable. I am not in a high-risk group if I do get COVID so I am willing to risk it.',
 'CB: default_3',
 "User: I'm not worried, and I won't be convincing anyone to do anything. Everyone should educated themselves and make their own decisions.",
 'User: Not enough research on the long term effects',
 'CB: long_term_1',
 'User: Exactly',
 'CB: default_1',
 "User: That's what they want you to think",
 'CB: default_2',
 'User: This is about control, not her immunity as the virus can still be spread',
 'CB: mutation_1',
 'User: Exactly so why are they vaccinating the masses without knowing the full story',
 'CB: default_3',
 "User: That's a load of rubbish",
 'User: I will consider its safety and effectiveness (how well it works) in people. It seems still not mature yet.',
 'CB: safety_1',
 'User: I think if I protect myself very well, I do not need to take it. However, so far taking a COVID-19 vaccine is a big risk.',
 'CB: default_1',
 'User: I know. I am looing forward to go back to normal life too. But people are normally afraid to unknown.',
 'CB: default_2',
 'User: If it is very effective and safe, I think I will consider taking it. So I may observe for some while first.',
 'CB: safety_2',
 'User: ok , I know the government has put great effort to monitor its process and effectiveness before releasing to the public.',
 'CB: default_3',
 'User: ok, once I get the vaccine, I believe my family will be willing to get it.',
 'User: abortion',
 'CB: default_1',
 'User: ransom',
 'CB: default_2',
 'User: if enough people have had the virus how does that too build herd immunity ?',
 'CB: default_3',
 'User: freedom of choice',
 'User: I don’t think it’s been tested enough. Don’t trust it ',
 'CB: safety_1',
 'User: But medications have been made before given out then it’s been found out years down the line it has adverse effects ',
 'CB: short_term_1',
 'User: How can they know about long term side effects in years to come ',
 'CB: long_term_1',
 'User: Exactly the reason it’s unlikely I will be taking up ',
 'CB: default_1',
 'User: I enjoy lockdown ',
 'CB: default_2',
 'User: Multiple vaccines all from different companies I find it difficult to trust ',
 'CB: default_3',
 'User: That hasn’t been proven yet fully ',
 'User: Firstly because I have various autoimmune symptoms and am very sensitive',
 'CB: default_1',
 "User: I understand that but as I said I'm really sensitive and could easily get a reaction if i have the vaccine",
 'CB: short_term_1',
 "User: I'm not talking about temporary side effects Im talking about long lasting ones",
 'CB: short_term_2',
 'User: As I said Im not talking about short term side effects Im talking about long term ones',
 'CB: long_term_1',
 "User: I also dont think this vaccine has been around long enough to know if it's safe",
 'CB: long_term_2',
 "User: What about the metal they put in the vaccines they put aliminium in there and that's really bad for you",
 'CB: default_2',
 "User: I'm not willing to sacrifice my own health for herd immunity",
 'CB: default_3',
 'User: I will have to worry about my health if I have a reaction to the vaccine',
 'END',
 'User: quit',
 "User: It's too soon, unknown side effects and unknown how long it's effective for",
 'CB: long_term_1',
 'User: I prefer my chances against Covid 19, I am young and healthy',
 'CB: young_1',
 'User: What about side effects',
 'CB: short_term_1',
 'User: The vaccine came too quickly, side effects may show in two years',
 'CB: short_term_2',
 'User: What about the vaccine side effects',
 'CB: default_1',
 "User: I don't believe that to be true",
 'CB: default_2',
 "User: The vaccine just reduces your chances, doesn't stop you getting it",
 'CB: default_3',
 'User: You can still get covid with the vaccine',
 "User: I'm not sure if it will be safe",
 'CB: safety_1',
 'User: I know, but I have to be completely sure of something I would be injecting into my body',
 'CB: default_1',
 'User: I have considered that but I would rather more people take it first',
 'CB: default_2',
 "User: How sure are we that something else won't spring up from the herd immunity?",
 'CB: default_3',
 'User: Sure, but what about possible side effects?',
 'CB: short_term_1',
 "User: Yes, but I don't want to risk having those side effects",
 'CB: short_term_2',
 "User: I don't know if my immune system would handle it",
 'CB: young_1',
 'User: Hmm',
 'User: adverse reaction',
 'CB: short_term_1',
 'User: im diabetic',
 'CB: default_1',
 'User: dangerous chemical',
 'CB: default_2',
 'User: it is against my religion',
 'CB: default_3',
 'User: religion come 1st',
 'User: test',
 'CB: safety_1',
 'User: test',
 'CB: safety_2',
 'User: test',
 'CB: safety_3',
 'User: test',
 'CB: short_term_1',
 'User: test',
 'CB: short_term_2',
 'User: test',
 'CB: default_1',
 'User: test',
 'CB: default_2',
 'User: test',
 'CB: default_3',
 'User: test',
 'END',
 'User: quit',
 'User: Feel it may have been rushed somewhat',
 'CB: fast_dev_1',
 'User: ok',
 'CB: default_1',
 "User: yes, that's one of the reasons I will probably have it as I want to travel. Seems we hae no choice otherwise",
 'CB: default_2',
 'User: I also wonder about the allergy part of the vaccine. My son has an auto immune disease',
 'CB: young_1',
 'User: ok',
 'CB: default_3',
 'User: still feel like I am being pushed towards a vaccine. I have stayed home worn masks, washed hands managed to not get the virus yet',
 'CB: mutation_1',
 'User: so we get the vaccine, and there is a new variant of the virus that does not react to the vaccines',
 'END',
 'User: quit',
 'User: Despite being tested on others, I fear for the side effects that may occur ',
 'CB: short_term_1',
 'User: ok',
 'CB: default_1',
 'User: yes, i do agree. but this can first be solved by people actually listening to the lockdown procedures',
 'CB: default_2',
 'User: YES',
 'CB: default_3',
 'User: I am still a little hesitant, but if it means helping resolve these issues yes',
 'User: I have my own thoughts',
 'CB: default_1',
 'User: No, risk is higher with low tested vac',
 'CB: safety_1',
 'User: It is only tested for 1yr',
 'CB: safety_2',
 'User: Sample of tests are limited',
 'CB: safety_3',
 'User: In compared, risks is lower if I self isolate',
 'CB: default_2',
 'User: There are people vaccinated still get infected',
 'CB: default_3',
 "User: We don't even know how long it lasts",
 'CB: long_term_1',
 'User: We do not know at what point the vaccine stops working',
 'User: There is no way of knowing the long-term side effects',
 'CB: long_term_1',
 "User: I've already had COVID and therefore already have the antibodies",
 'CB: default_1',
 'User: Herd immunity can be achieved without the vaccine',
 'CB: default_2',
 "User: Nature's immunity is strong enough without a vaccine",
 'CB: default_3',
 'User: My family and I all have the antibodies',
 'User: I am not sure how safe it is',
 'CB: safety_1',
 'User: Some people have complained about side effects that last a long time',
 'CB: long_term_1',
 'User: Ok',
 'CB: default_1',
 "User: I think so, but if every one else takes it i don't have too",
 'CB: default_2',
 'User: Allergy to sea foods',
 'CB: default_3',
 'User: That is true',
 'User: Because I am only 19 and don’t want to be something in my body that I don’t have to ',
 'CB: default_1',
 'User: But the likelihood of me being effected by the virus in a fatal way is very slim',
 'CB: mutation_1',
 'User: I know ',
 'CB: default_2',
 'User: But it has already been said that if you have the vaccine you can still spread it ',
 'CB: default_3',
 'User: I am not worried about my health right now as I am healthy and I will only be effected by the virus in a small way like a cold or flu',
 'CB: young_1',
 'User: Video voted',
 'User: Not confident in it. Took very little time to develop',
 'CB: default_1',
 "User: I get it. I just don't want to be forced into it",
 'CB: default_2',
 'User: ok',
 'CB: default_3',
 'User: Not to worry about my health? I\'ve got bigger problems than getting "bigger flu"',
 'CB: flu_1',
 'User: People die from flu as well. ',
 'CB: flu_2',
 "User: It is important. People shouldn't be pushed into something if they are not comfortable with it. It is important to know ALL and EVERY detail about vaccine you put into your body",
 "User: I don't feel I need one - I'm not a vunerable group",
 'CB: default_1',
 'User: Well yeah, if I HAVE to have one to travel then I will',
 'CB: default_2',
 'User: ok',
 'CB: default_3',
 "User: some people don't get vaccines for anything, in general",
 "User: I don't believe extensive testin gon black people has been carried out",
 'CB: safety_1',
 'User: but they were not tested for as long as vaccines are usually tested for',
 'CB: safety_2',
 'User: they can not know what the long term side effects are as the testing was so short',
 'CB: long_term_1',
 'User: there are a percent of people who can not take vaccines anyway ',
 'CB: default_1',
 "User: being able to go out with friends isn't worth the risk of long term health issues the vaccine may bring",
 'CB: long_term_2',
 'User: the testing is never diverse',
 'CB: safety_3',
 'User: the vaccine was tested by having 2 doses within a couple of weeks and the government have changed this with regard to if it is still effective',
 'CB: mutation_1',
 'User: you need a second dose at 21 days which is being delayed',
 'CB: default_2',
 'User: a hostory of covid should technically work in the sam eway as the vaccine if the dose is not active',
 'CB: default_3',
 'User: but you can still get ill after a vaccine, people who get the mmr can still gets mumps for example',
 'User: long term effects unknown',
 'CB: long_term_1',
 'User: will it cause infertility',
 'CB: default_1',
 'User: i cant trust it ',
 'CB: default_2',
 'User: what if it causes birth deffects',
 'CB: default_3',
 'User: ive already had covid to i need immunisation',
 'User: i had covid',
 'CB: default_1',
 'User: vaccine havent been tested properly',
 'CB: safety_1',
 'User: it was forced',
 'CB: default_2',
 'User: ok',
 'CB: default_3',
 'User: ok',
 'User: yea i want a covid-19 vaccine',
 'CB: default_1',
 'User: yes true back to normal',
 'CB: default_2',
 'User: aham',
 'CB: default_3',
 'User: i`m trying to convince them as well',
 'User: it may have side effects',
 'CB: short_term_1',
 'User: i would rather wait until those side effects are reduced to acceptable level',
 'CB: short_term_2',
 'User: but those can be harmful to your body',
 'CB: default_1',
 'User: i wonder are these vaccine really working or not',
 'CB: default_2',
 'User: are they also working to the new variant',
 'CB: default_3',
 'User: what about the new variant ',
 'User: i am worried it might be detrimental to my health',
 'CB: default_1',
 'User: but i heard rumours it contained aborted fetuses',
 'CB: default_2',
 'User: what if i die from the vaccene',
 'CB: default_3',
 'User: not really, since the virus can evolve and mutate so theoretically i could still get a strain of the virus even after taking the vaccine',
 'CB: mutation_1',
 "User: the vaccine moved way too quickly through the testing trials, so i don't think it has had long enough to become tested and safe",
 'CB: safety_1',
 "User: i heard the vaccine works with mrna, meaning genetically modified deoxyribonuclaic acid, and as far as i know, the implications of mrna aren't fully understood",
 'User: I don’t think the Covid 19 vaccine has been thoroughly tested ',
 'CB: safety_1',
 'User: Steps might not have been skipped, but I’m not sure I trust any of the data from the trials. These developers may have other agendas ',
 'CB: default_1',
 'User: I understand that but what if this is all a conspiracy anyway? The government could have ulterior motives for stalling sections of the economy and controlling the population in this way ',
 'CB: default_2',
 'User: I’m not sure that it is. This vaccine has been passed too quickly. I don’t understand how they can find a vaccine so quickly for this but not other things like cancer  ',
 'CB: fast_dev_1',
 'User: I don’t believe that. Other illnesses and viruses get a lot of funding and still are virtually no further forward',
 'CB: default_3',
 'User: I’m not worried about my health at the moment. I’m washing my hands and wearing a mask. I’m doing the best I can and my family and friends are too. I’m worried if they get the vaccine there may be side effects from it',
 'CB: short_term_1',
 'User: Short term side effects could be very detrimental for some people. I am concerned how my body would react to the vaccine ',
 'CB: short_term_2',
 'User: I don’t have a good immune system anyway, and whilst this may be an incentive for getting the vaccine I also worry that it could be worse ',
 'CB: young_1',
 'User: Long Covid does sound really bad, but it’s still not enough to convince me to get the vaccine yet. I want to wait and see what happens as the programme is rolled out',
 'CB: long_term_1',
 'User: I think it’s too early to speculate that long term effects are more likely from Covid than they are the vaccines. People thought for many years smoking was safe before realising it wasn’t ',
 'CB: long_term_2',
 'User: Science is wonderful but it isn’t always right. This programme has been rushed and I’m not convinced the vaccine is right for me despite being a frontline worker',
 'CB: fast_dev_2',
 'User: If that was the case then they should be able to find cures or vaccines to other serious illnesses, again like cancer']

# %%
logs_2= ['User: Don’t need it ',
 'CB: default_1',
 'User: Sound like blackmail to me ',
 'CB: default_2',
 'User: I don’t agree ',
 'CB: default_3',
 'User: It is not proven to eliminate all risk relating to covid ',
 'User: These vaccines are invented too fast compared with other vaccines. I would like to know more about the side effects of these vaccines. ',
 'CB: short_term_1',
 'User: Thanks',
 'CB: default_1',
 'User: Yes, I agree. ',
 'CB: default_2',
 'User: Definitely.',
 'CB: default_3',
 'User: Right. But I still have concerns.',
 "User: We haven't had enough time to test it",
 'CB: default_1',
 "User: That would be nice, but let's not be unrealistiv",
 'CB: default_2',
 "User: New Zealand/ Australia are COVID-19 free without a vaccine. Herd immunity isn't the only solution.",
 'CB: default_3',
 "User: I would worry because, like I mentioned before, we don't know the long term effects. Eg. How it will affect fertility - women looking to get pregnant in the future",
 'CB: long_term_1',
 "User: Nevertheless, long term effects are still an issue. We can't predict the future.",
 'CB: long_term_2',
 'User: There are multiple vaccines; each containing different ingredients.',
 "User: hasn't been tested properly ",
 'CB: safety_1',
 'User: ok',
 'CB: default_1',
 'User: because it requires 3 years for accuracy',
 'CB: default_2',
 'User: ok',
 'CB: default_3',
 'User: ok',
 "User: i don't think i am at risk.",
 'CB: default_1',
 "User: i've considered this fear tactic, yes.",
 'CB: default_2',
 'User: why should anyone NOT be allowed to get it in the first place?',
 'CB: default_3',
 "User: because they're perfectly healthy",
 'CB: young_1',
 'User: maybe we should stop playing with "agent orange" and go back to church already.',
 "User: It all happened too quickly. How are they sure that there aren't side effects that they are currently unsure of?",
 'CB: short_term_1',
 'User: What about long term side effects?',
 'CB: long_term_1',
 'User: How can the government be so sure that the vaccine works?',
 'CB: default_1',
 'User: Why is the vaccine been pushed so heavily? ',
 'CB: default_2',
 'User: Even the responses here seem so scripted. Everything is so scripted regarding this vaccine',
 'CB: default_3',
 'User:  What is in the vaccine?',
 'User: I don’t want to take it as I believe it’s been rushed, I feel weary of a vaccine that’s been created in 8 months. I am also a young female and I would like to have children in the near future, I do not want my fertility to be affected',
 'CB: default_1',
 'User: Yes but having children is more important to me',
 'CB: default_2',
 'User: No as the virus will mutate and will cause another strain and outbreak',
 'CB: mutation_1',
 'User: I still do not agree. You should not rush into a vaccine that has been produce in 8 months ',
 'CB: default_3',
 'User: I will have to worry as it affects fertility ',
 'User: Because it hasn’t had enough testing ',
 'CB: safety_1',
 'User: Other vaccines take longer to become available to the public this one is too quick ',
 'CB: fast_dev_1',
 'User: Fair enough but what about side effects ',
 'CB: short_term_1',
 'User: I don’t trust it ',
 'CB: default_1',
 'User: That’s fair but I won’t be taking it',
 'CB: default_2',
 'User: So they should only vaccine the high risk groups ',
 'CB: default_3',
 'User: You don’t know that ',
 'User: im not sure the vaccine is safe',
 'CB: safety_1',
 'User: it was developed too quickly',
 'CB: default_1',
 'User: COVID-19 has a 99% survival rate',
 'CB: default_2',
 'User: the government lies about the safety of the vaccine ',
 'CB: safety_2',
 'User: COVID-19 is caused by 5G cell towers',
 'CB: default_3',
 'User: they suck',
 'END',
 'User: quit',
 'User: I just don’t trust it',
 'CB: default_1',
 'User: But what are the side effects',
 'CB: short_term_1',
 'User: If it was made so quickly how do you know that it works',
 'CB: fast_dev_1',
 'User: How do you know it works',
 'CB: default_2',
 'User: If there is herd immunity then I won’t need one',
 'CB: young_1',
 'User: But what if I never get it',
 'CB: default_3',
 'User: I will probably be one of the last to get it so there is no point',
 "User: I am concerned about it's safety",
 'CB: default_1',
 "User: I won't risk myself just because people need to travel or go out",
 'CB: default_2',
 'User: people wearing masks, washing hands and keep social distancing are also indicated as necessary ways. vaccine is not the only choice',
 'CB: default_3',
 'User: people can still get infected after getting the vaccine',
 'CB: get_covid_1',
 "User: who can make sure there won't be any side effects after several years?",
 'CB: short_term_1',
 'User: what about long term effects?',
 'CB: long_term_1',
 "User: I am afraid that the vaccine is moving put from clinical trails too fast to be considered as 'safe enough'",
 'User: Well I have heard from NHS professionals that doctors are divided whether it is safe to take if you are pregnant. I am not currently pregnant but I don’t want any adverse side effects if I do decide to start a family.',
 'CB: short_term_1',
 'User: AnNHS professional told me that it effects fertility in women for up to 8 months. If this is what we know now, what further side effects could we know in 10 years?',
 'CB: short_term_2',
 'User: My boyfriends grandpa received the covid vaccine and2',
 'CB: default_1',
 'User: *my boyfriends grandpa received the covid vaccine and 2 days later was hospitalised with a severe chest infection. With regards to your point about herd immunity, it’s a virus that will continue to mutate - once it is in our society it will not go away completely - unfortunately that is the nature of a virus.',
 'CB: mutation_1',
 'User: The flu vaccine needs to be redeveloped and administered every year to continue having an effect, as flu viruses mutate too. So yes, covid mutating would mean that the vaccine is redundant depending on what strain of the virus you have.',
 'CB: mutation_2',
 'User: But it has been shown that having the vaccine does not prevent you from becoming infected again, nor does it prevent you from infecting other people. So why have it? That is not a credible vaccine.',
 'CB: get_covid_1',
 'User: How can a credible vaccine be developed in such a short space of time though? Doctors have speculated how it can be developed so quickly when vaccines normally take years to develop and monitor adverse side effects.',
 'CB: default_2',
 'User: I believe that those who cannot afford to contract the virus (e.g. immune compromised, prior health conditions, etc.) should receive it. However those with a healthy immune system should be able to choose and not have the vaccine forced upon them. Healthy people being exposed to it and building up a natural tolerance will also create herd immunity.',
 'CB: young_1',
 'User: Quit',
 "User: i'm waiting for research on the long term effects of the vaccine and the effectiveness between variants",
 'CB: long_term_1',
 "User: but if i'm just being at home why would I need the vaccine?",
 'CB: default_1',
 'User: but will it work against different variants?',
 'CB: mutation_1',
 'User: which vaccine do we know is the most effective',
 'CB: default_2',
 "User: i don't trust the vaccine as it was approved too quickly",
 'CB: fast_dev_1',
 'User: where are the results from these trials?',
 'CB: default_3',
 'User: but there are side effects to the vaccine',
 'CB: short_term_1',
 'User: allergic reaction to the vaccination has not been ruled out',
 'CB: short_term_2',
 'User: but i could also get covid but only mild symptoms ',
 'User: I still uncertain at the moment, but will take it when I am certain it is safe.',
 'CB: safety_1',
 'User: Okay.',
 'CB: default_1',
 'User: This is what we all want to return to normal.',
 'CB: default_2',
 'User: okay.',
 'CB: default_3',
 'User: yes.',
 'User: Im an anti vaxxer',
 'CB: default_1',
 'User: nope not gonna happen its all part of the New World Order and population control, its not a vaccine its an mrna',
 'CB: default_2',
 'User: never worked for flu variants people got ill some died',
 'CB: default_3',
 'User: ha ha us anti vaxxers will be the only healthy ones left',
 'CB: young_1',
 'User: seen it...rubbish',
 'User: alien dna',
 'CB: default_1',
 'User: what about the alien dna in the vaccine',
 'CB: default_2',
 'User: your not talking about the alien dna',
 'CB: default_3',
 'User: why the same message again and again dumb robot',
 "User: I DON'T KNOW WHAT THEY ARE PUTTING INTO MY BODY AND THE HEALTH IMPLICATIONS LATER ON.",
 'CB: default_1',
 'User: maybe, but I should be able to choose whether I want this muck or not as it is my health.',
 'CB: young_1',
 'User: I am not young, I am in my fifties and I worry anyway that by putting some of that covid into me by vaccine that I may get it.',
 'CB: default_2',
 "User: whatever, I personally don't want it and I won't be having it.",
 'CB: default_3',
 "User: None of my friends want the vaccine either, like me they don't trust it! I'm not worrying about covid 19, I will just take my chances with it.",
 'User: Uncertainty that it will work',
 'CB: default_1',
 'User: I would rather stay at home indoors like this and be safe',
 'CB: safety_1',
 "User: But again it's there word we have to risk our lives on",
 'CB: default_2',
 'User: Again no guarantee it will 100% work',
 'CB: safety_2',
 'User: Because until I see clear cut evidence that this is working, I will not change my mind',
 'CB: default_3',
 'User: Yes I have considered that but I have managed 11 months',
 'User: Because I am against it ',
 'CB: default_1',
 'User: No, that is a lie. The vaccine is bad',
 'CB: default_2',
 'User: Who says the vaccine will be truly good for us ',
 'CB: default_3',
 'User: Getting the vaccine does not guarantee safety anyway ',
 'User: Because the effects of long term havent been proven',
 'CB: long_term_1',
 'User: yes thats true on both cases, but why should i trust whatever the people making the vaccine to have the best interest in it for me in the long run when i personally dont know the materials used in the vaccine, so to me the effects of covid 19 could just be the effects of a flu and be done and over with, when the effects of a vaccine could be long term worse in 10 years or whatever like that. the vaccines i have taken before such as the flu vaccines; ended up making me more sick for a short time then the flu would of normally.',
 'CB: long_term_2',
 'User: that still doesnt tell me how its going to effect me ',
 'CB: short_term_1',
 'User: but how do i know what even the symptoms of covid 19 will be for me as they are different for everyone including some being asymptomatic ',
 'CB: default_1',
 'User: I have reasonable doubt that normal life will ever be the same as it once was.',
 'CB: default_2',
 'User: but saying its safe doesnt 100% make it safe. lots of things in the past have had issues we never calculated.',
 'CB: safety_1',
 'User: That may be true but how do we know whats going to go further into the vaccine, especially if its like the flu and going to just mutate further as there are already other variants some that are more resilient to vaccines',
 'CB: mutation_1',
 'User: 99 percent, so far its still only barely new, again what happens to our kids or further down the line with these variants how can we be sure to something that we can hardly predict',
 'CB: default_3',
 'User: wont have to worry about it for now, though but how long is that really gunna last, could be tomorrow a new one that pops up and isnt just as easily treatable',
 'CB: long_term_3',
 'User: the way i see it is a 50/50 toss up youre stuck regardless of you getting the vaccine or not getting the vaccine the only surefire way to fully stop the spread is not be exposed, and how is that even possible when people dont even follow the rules as it is.',
 'CB: get_covid_1',
 'User: Its not a problem until it is a problem',
 'User: Future problems ',
 'CB: short_term_1',
 'User: Scary',
 'CB: default_1',
 'User: True but we could die',
 'CB: default_2',
 'User: It could cause problems in years time',
 'CB: default_3',
 'User: I know but it’s not been tested for long',
 'CB: long_term_1',
 'User: I don’t know',
 'User: because I am sceptical about the vaccine ingredients',
 'CB: default_1',
 'User: Sure, but what about the side effects?',
 'CB: short_term_1',
 'User: Eh, would rather not have one than manage the side effects',
 'CB: short_term_2',
 'User: I am also looking into getting pregnant by the end of this year, not definite yet, but thinking about it',
 'CB: default_2',
 "User: yeah, O'm not sure your one point addresses my concerns at all. Lol",
 'CB: default_3',
 "User: Well, I mean, the vaccine doesn't eradicate all illnesses",
 'CB: get_covid_1',
 "User: But that's just for coronavirus",
 'User: because of side effects',
 'CB: short_term_1',
 'User: exactly, this vaccine was very short development',
 'CB: default_1',
 "User: probably that's what will happen. Lot's of people will vaccine just because they need to travel for work",
 'CB: default_2',
 'User: Yes I have considered it, maybe you are right',
 'CB: default_3',
 "User: I disagree at this point, because vaccination doesn't mean you will never get infected, plus we don't know about side effects as well. i am especially worried about my parents and elderly people",
 'CB: short_term_2',
 'User: what about long term side effects?',
 'CB: long_term_1',
 'User: That is why it is hard to decide to vaccinate or not',
 'User: the governent',
 'CB: default_1',
 'User: and the government will have more control',
 'CB: default_2',
 'User: because',
 'CB: default_3',
 'User: yes i have, but we dont knwo whats in it',
 'User: I do not want to take an untested vaccine',
 'CB: default_1',
 "User: this isn't a normal vaccine",
 'CB: safety_1',
 'User: but no long term effects have been tested',
 'CB: long_term_1',
 'User: ok',
 'CB: default_2',
 'User: no because it does not provide herd immunity ',
 'CB: default_3',
 'User: but you can still catch it?',
 'CB: get_covid_1',
 'User: no because you can still catch it and get ill',
 'CB: safety_2',
 'User: yet they are dying in huge numbers after getting the vaccine',
 'CB: death_1',
 'User: the evidence shows that elderly people in care homes are dying ',
 'CB: safety_3',
 'User: I disagree. There is evidence that people are dying after having the vaccine',
 'User: They have not been tested properly and proper research has not been done on them',
 'CB: safety_1',
 'User: It needs to be further investigated ',
 'CB: default_1',
 'User: Yes but we don’t know the side effects of the vaccine, whos to say the vaccine won’t bring worser causes?',
 'CB: short_term_1',
 'User: It hasn’t been around long enough to know whether or not there are any long term symptoms ',
 'CB: long_term_1',
 'User: If you do not know about any long term effects then why release the vaccine? Is that not just creating a bigger risk for everyone who takes the vaccine?',
 'CB: long_term_2',
 'User: The vaccine may not even last for that long, it’s still possible for people to catch covid after they’ve taken the vaccine',
 'CB: default_2',
 'User: It will not protect us forever though.',
 'CB: default_3',
 'User: The vaccine hasn’t been tested enough for anyone to say that I won’t have to worry about my health, it could have severe long term effects that have not yet been identified ',
 'CB: long_term_3',
 'User: Covid has been around for a while now so if there were any long term effects it would mainly be to do with the respiratory system as thats the area the virus attacks. ',
 'CB: long_term_4',
 'User: Yes but you can only assume, you are not 100% sure that the vaccine is correct',
 'CB: get_covid_1',
 'User: There might not be enough vaccinations to be given to everyone and everyone may not be able to afford to have a vaccine',
 'CB: fast_dev_1',
 'User: If the vaccine has been rushed then it has not been investigated properly. Scientists should be taking their time to look into the virus properly in order to develop one vaccine that will help not loads of other vaccines that all have different effects',
 "User: I don't want to inject my body with a foreign vaccine where i do not know the long-term effect",
 'CB: long_term_1',
 'User: Thanks',
 'CB: default_1',
 "User: I'm being safe by staying in at the moment and letting the older generation get their vaccines now ",
 'CB: safety_1',
 'User: Step?',
 'CB: default_2',
 "User: I'm not willing to take it unless absolutely necessary ",
 'CB: young_1',
 "User: Hmm maybe I'll give that a watch later. Back to the point, i haven't done much investigating myself so i wouldnt take it until I've considered different things",
 'CB: default_3',
 "User: How can you say that for certain? You can't guarantee that so you can't state that as a fact",
 'CB: get_covid_1',
 "User: Again, you don't know that for certain. We have no proof to say you can't still transmit the virus",
 "User: I don't think it has been around for long enough",
 'CB: long_term_1',
 'User: It is more about whether enough research has been done ',
 'CB: default_1',
 "User: Yes however I don't feel I need it as much as others. I am not clinically vulnerable or elderly",
 'CB: default_2',
 'User: Will that ever be fully achieved though?',
 'CB: default_3',
 "User: I am all for people getting the vaccine, I just don't think I am in need of it as much as others",
 'User: Scared of needles ',
 'CB: default_1',
 'User: Side effects',
 'CB: short_term_1',
 'User: Getting ill ',
 'CB: get_covid_1',
 'User: Doesn’t stop you from getting the virus ',
 'CB: default_2',
 'User: Not everyone will get it so here immunity can’t be created',
 'CB: default_3',
 'User: Normality will take ages',
 'User: because it has been made so quickly',
 'CB: fast_dev_1',
 'User: because you cant just make a vaccine in a year',
 'CB: default_1',
 'User: people are dying from the vaccine',
 'CB: death_1',
 'User: you can still get covid from it',
 'CB: get_covid_1',
 'User: development has been rushed',
 'CB: fast_dev_2',
 'User: i see',
 'CB: default_2',
 'User: i enjoy sitting at home',
 'CB: default_3',
 'User: i am not worried about my health',
 'CB: young_1',
 'User: pk',
 "User: doesn't protect against all strains",
 'CB: default_1',
 "User: vaccine doesn't mean you can't spread the virus",
 'CB: get_covid_1',
 'User: it is a problem - people can still infect others',
 'CB: default_2',
 'User: virus will still spread',
 'CB: default_3',
 'User: wait is too long to get vaccine',
 'CB: long_term_1',
 'User: too many different vaccines',
 'User: it is dangerous to human body',
 'CB: default_1',
 'User: that is not a valid argument why i should get it in the first place',
 'CB: default_2',
 'User: what about people who already contained virus?',
 'CB: default_3',
 'User: that is non sense, even if the vaccine was the only cure, we should have multiple shots in such a short time',
 'END',
 'User: quit',
 'User: I do not want to take a COVID-19 vaccine once one becomes available to me because this vaccine has not been tested for an extented period of time and we do not know the side effects that people will maybe get in a couple of years',
 'CB: default_1',
 'User: No, is it said that the vaccine makes females to not be able to give birth in the future.',
 'CB: default_2',
 'User: No, i still do not want to take a COVID-19 vaccine because it can contain a microchip that locates me.',
 'CB: get_covid_1',
 'User: No, because some people that have been vaccinated say that they had side effects (e.g.trembling).',
 'CB: short_term_1',
 'User: It still not tested enought. Usually, vaccines are getting tested for years before given to the public.',
 'CB: safety_1',
 "User: No, i still do not want to get a COVIS-19 vaccine. In the news i heard that people get two different vaccines during the two stages of the vaccination and not the same ''brand'' of the vaccine! ",
 'CB: default_3',
 'User: We are still not 100% sure about its effectiveness. News said that it can not protect you from the new covid-19 type that has been found in Africa.',
 'User: The vacine is extremely new and could have anything inside of it',
 'CB: default_1',
 'User: Yes but, there could be something in the vacine to kill us off slowly',
 'CB: default_2',
 "User: The vacine hasn't been around for long so we don't know whether it'll work",
 'CB: long_term_1',
 "User: There could be so many side effects that we don't know about",
 'CB: short_term_1',
 'User: There are so many different vacines why is there not just 1 vacine that makes you immune',
 'CB: default_3',
 'User: the vacine may be a lie though',
 "User: i don't know what is in the vaccine",
 'CB: default_1',
 'User: there are other ways to be able to achieve that ',
 'CB: default_2',
 "User: but we don't know how effective the vaccine is",
 'CB: default_3',
 'User: some people are naturally recovering from covid without taking any medication',
 'User: I dont feel like i need it, covid has an aboce 95% survival rate. I would rather other people with compromised immune systems get it first',
 'CB: default_1',
 "User: I agree, and that's why a lot of other people should get vaccinated. people wth compromised immune systems and older people",
 'CB: default_2',
 'User: i mean with a virus that has a 95% survival rate. we would achieved that regardless but yes this is a safer way. people getting the virus can make them immune',
 'CB: default_3',
 'User: the vaccine also has a percentage of getting me sick or my body not reacting to it properly. so tomatoes, tomata',
 "User: Because I believe that these vaccines have been rushed through development a little too hastily, and not enough time has been established to identify any long term side affects or other problems. Plus I have concerns about the 'no-liability' clause.",
 'CB: default_1',
 "User: We should be allowed to do that anyway. These lockdowns should never have happened, in my opinion. Here in Britain, they've clearly been unsuccessful.",
 'CB: default_2',
 'User: Even against the new variants? For every vaccine breakthrough, there are plenty of mutations taking place that may or may not render them useless.',
 'CB: mutation_1',
 "User: If you say so, but the news only today about the 'South African variant' has been pretty discouraging. People can have the vaccine if they like, just respect the wishes of those of us who may not.",
 'CB: default_3',
 "User: Nonsense! We ALWAYS have to look out for our health. Vaccines don't make us invincible.",
 'User: Currently TTC and dont trust the vaccine',
 'CB: default_1',
 'User: Thats true',
 'CB: default_2',
 'User: No it doesnt stop us from getting covid',
 'CB: get_covid_1',
 'User: Yes but no1 really knows whats in the vaccine ',
 'CB: default_3',
 'User: Not true. I worry more that our vulnerable family have already taken it',
 'User: Because my body is healthy as it is',
 'CB: young_1',
 'User: Because it has stupid side affects ',
 'CB: short_term_1',
 'User: I don’t trust doctors ',
 'CB: default_1',
 'User: I don’t have a need for it as I stay at home  ',
 'CB: default_2',
 'User: I don’t take medicine or drugs',
 'CB: default_3',
 'User: My body may react to it ',
 'User: Because I feel it’s been brought out too quickly',
 'CB: fast_dev_1',
 'User: Side effects are still unknown ',
 'CB: short_term_1',
 'User: I’m worried about the long term side effects of which we cannot be certain of until some time has passed',
 'CB: long_term_1',
 'User: I would rather take the risk with my own immune system than take a risk with the foreign bodies from a vaccine',
 'CB: young_1',
 'User: Many many people survive from Covid and we only hear about the bad cases ',
 'CB: default_1',
 'User: I feel',
 'CB: default_2',
 'User: We cdd as m',
 'CB: default_3',
 'User: We can achieve herd immunity through our own bodies defence ',
 'END',
 'User: Quit',
 'User: The virus has a high survival rate',
 'CB: default_1',
 'User: We will see about that',
 'CB: default_2',
 "User: I don't believe that, it's all panto and drama",
 'CB: default_3',
 'User: I will not be convincing anyone to get an experimental vaccine.',
 'User: It is not a highly infectious deadly virus',
 'CB: default_1',
 'User: Vaccines are not needed to achieve herd immunity.',
 'CB: default_2',
 'User: Allowing the virus to spread without a vaccine would also create herd immunity.',
 'CB: default_3',
 "User: I don't have to worry about my health anyway.",
 'User: I dont think the vaccine is safe',
 'CB: safety_1',
 'User: yeah but they all didnt got enough time to test the vaccine properly ',
 'CB: safety_2',
 'User: there is actually a reasons',
 'CB: default_1',
 'User: why they do start with the elderly people with so many heart conditions then ',
 'CB: default_2',
 'User: why they dont do that with normal people ',
 'CB: default_3',
 'User: there would be no such positive results , or they wont have who to blaim then ',
 'User: There are more important people that need than me. I’ve just finished my isolation period after testing positive and had no symptoms at all. Only knew I was positive because I test regularly for working in a school. ',
 'CB: safety_1',
 'User: Long term affects won’t be known for a long time. ',
 'CB: long_term_1',
 'User: Being 26 and having just had Covid 19 with no symptoms, long covid does not affect me. ',
 'CB: long_term_2',
 'User: That’s also a hypothetical argument. Despite the differences there could still be long term health implications that are currently unknown. ',
 'CB: long_term_3',
 'User: Depending on your age. ',
 'CB: default_1',
 'User: I think that will happen if everyone over a certain age where covid is affecting them are vaccinated. Shouldn’t be forced upon younger people. ',
 'CB: get_covid_1',
 'User: But we still don’t know how often everyone would need to be vaccinated abs how long immunity lasts. ',
 'CB: long_term_4',
 'User: Assumptions aren’t good enough for me. ',
 'CB: default_2',
 'User: You’ve just argued that you can still transmit it with the vaccine so I don’t believe it will protect us all if there are people unable to get it. ',
 'CB: death_1',
 'User: I hadn’t heard of people dying from it. ',
 'CB: default_3',
 'User: I think everyone worries about there health regardless and there are many other viruses about such as flu. ',
 'User: I believe it is not necessary for me as I am not in a risk group ',
 'CB: young_1',
 'User: Okay thanks ',
 'CB: default_1',
 'User: Okay, that actually makes sense',
 'CB: default_2',
 'User: Okay, I understand ',
 'CB: default_3',
 'User: I do agree',
 'User: IT DOES NOT PREVENT ME FROM GETTING It ',
 'CB: get_covid_1',
 "User: if the queen has the vaccine I've then i will",
 'CB: default_1',
 'User: herd immunity only works if its mandatory ',
 'CB: default_2',
 'User: stated already the vaccine does not prevent you from hgettingf it so how would herd immunity work',
 'CB: default_3',
 'User: lol bot got jokes i would never advise my family to do such a thing ',
 'END',
 'User: quit',
 'END',
 'User: quit',
 'User: It may not be totally necessary for my age group',
 'CB: young_1',
 'User: I think i have already had it in the summer',
 'CB: default_1',
 'User: What about the constantly changing variants',
 'CB: mutation_1',
 'User: What if it is harmful',
 'CB: default_2',
 'User: The clinical trials dont seem to include the elderly',
 'CB: default_3',
 'User: What if the vaccine has been rushed ',
 'CB: fast_dev_1',
 'User: What about the adverse side effects ',
 'CB: short_term_1',
 'User: Some people have had serious side effects ',
 'CB: short_term_2',
 'User: What about the South African strain',
 'User: because i feel it has been rush through and not properly tested',
 'CB: safety_1',
 'User: no one knows long term affects of vaccines',
 'CB: long_term_1',
 'User: people eventually get over long covid',
 'CB: long_term_2',
 'User: the virus mutates so you never have an accurate vaccine',
 'CB: mutation_1',
 'User: and the the vaccine never stops you getting covid',
 'CB: get_covid_1',
 'User: whas the differece between covid 19 and other covid strains?',
 'CB: default_1',
 'User: because I am not responsible for other peoples health, only my own',
 'CB: default_2',
 'User: I wouldnt throw myself under a bus to save someone else.',
 'CB: default_3',
 'User: because I am healthy',
 'CB: young_1',
 'User: i understand',
 'END',
 'User: quit',
 'User: I don’t think it’s safe',
 'CB: safety_1',
 'User: But we are still not sure about the long term effects',
 'CB: long_term_1',
 'User: But what if in a few years serious side effects emerge?',
 'CB: short_term_1',
 'User: Is it safe for children?',
 'CB: safety_2',
 'User: How can people die from it?',
 'CB: death_1',
 'User: The vaccine was made too quickly in my opinion',
 'CB: fast_dev_1',
 'User: But what if companies manipulated steps to get out first?',
 'CB: default_1',
 'User: Covid seems to be going anyways',
 'CB: default_2',
 'User: What if herd immunity doesn’t work?',
 'CB: default_3',
 'User: People are still scared. ',
 "User: I'm afraid to it making me catch the covid 19 strain and I get ill and die",
 'CB: default_1',
 'User: But we do not have a vaccine for all strains of the virus',
 'CB: mutation_1',
 'User: What about the non UK version of the virus as those are deadly',
 'CB: default_2',
 'User: But you can still catch the virus after having the vaccine',
 'CB: mutation_2',
 "User: But we don't know the side affects of the vaccine on future generations ",
 'CB: short_term_1',
 'User: But there is no data on the long term side affects of using the vaccine',
 'CB: long_term_1',
 'User: But do we know what it will do for the next generation ',
 'CB: default_3',
 'User: But you can still die from covid 19 after you have taken the vaccine',
 'User: i dont think there has been enough testing and i think as its not 100% effective the likelihood of catching covid 19 wont be reduced enough to be effective',
 'CB: default_1',
 'User: i dont think herd immunity will be effective in this case but i would love to meet friends and family',
 'CB: default_2',
 'User: unfortunaely it wont protect us all',
 'CB: default_3',
 'User: not true, until covid is erradicated there will always be a risk and reason to worry',
 "User: i do not want the vaccine because it has been developed in a short amount of time, so i'm not sure if it is safe",
 'CB: safety_1',
 'User: most vaccines take years to make',
 'CB: default_1',
 'User: why can they not just create more restrictions right now and lockdown. For people that do not listen give them fines and jail time',
 'CB: default_2',
 'User: it is not the only safe way. i think it is morally wrong to make everyone get a vaccine. I find it suspicious that countries may not let people in who do not get the vaccine.',
 'CB: default_3',
 'User: Alot of people have had bad reactions such as facial paralysis',
 'CB: short_term_1',
 'User: I would rather other people take it and give it a couple years so we can see the effects it has. then i will consider getting it.',
 'User: because I think it may be dangerous for my health',
 'CB: young_1',
 'User: ok',
 'CB: default_1',
 'User: yes I have ',
 'CB: default_2',
 "User: it's my choice",
 'CB: default_3',
 "User: I don't have to explain to you - you are a robot",
 "User: it is dangerous and causes cancer and changes your dna, also sleepie joe things it'll be good so you know it's bad",
 'CB: default_1',
 'User: we should just do that now',
 'CB: default_2',
 'User: just catch it to get heard immunity?',
 'CB: default_3',
 "User: i will because they'll get cancer =)",
 'User: worried about the safety of vaccine ',
 'CB: default_1',
 'User: i understand but',
 'CB: default_2',
 'User: is it effective',
 'CB: default_3',
 'User: ok',
 'User: I have a chronic illness of the brain and do not want further side effects',
 'CB: short_term_1',
 'User: I do not believe they would be short term',
 'CB: default_1',
 'User: what is normal',
 'CB: default_2',
 'User: Horrible humans have treated animals, nature and the planet without respect for centuries, if humans believe Madame Mother Nature does not have another trick to show us how horrible we have been, you are silly',
 'CB: default_3',
 'User: Rubbish, I have a brain disease',
 "User: Because it hasn't been tested for very long",
 'CB: long_term_1',
 'User: however the long term effects from covid are more of an issue for older people or those with pre existing medical condition',
 'CB: long_term_2',
 "User: but there is still no need for me to have it if i am not at high risk, just like i don't have the flu vaccine every year",
 'CB: default_1',
 'User: it is still a personal choice',
 'CB: default_2',
 "User: it won't stop us all get the virus as the vaccine does not 100% guarantee that",
 'CB: default_3',
 "User: I will have to worry about my health as the vaccine is not 100% guarantee you won't get the virus and i will have put something in my body that i know nothing anout",
 'User: It has not had the long term effects tested ',
 'CB: long_term_1',
 'User: I don’t think COVID-19 would be dangerous to me',
 'CB: default_1',
 'User: But that is at the risk of illness or defect from the vaccine ',
 'CB: default_2',
 'User: The vaccine was made too quickly ',
 'CB: fast_dev_1',
 'User: No amount of money can see how this vaccine would affect us in the long run',
 'CB: long_term_2',
 'User: How can we vaccinate against a virus which changes ',
 'CB: mutation_1',
 'User: Then why don’t we vaccinate against all viruses',
 'CB: mutation_2',
 'User: The companies who made the vaccines are exempt from lawsuits which is suspicious ',
 'CB: default_3',
 'User: I am not worried about my health anyway ',
 'CB: young_1',
 'User: The risks of long COVID are smaller than the risk from the vaccine',
 'CB: long_term_3',
 'User: There is no way to prove it is more likely',
 'User: I personally feel the vaccine can cause detrimental side affects',
 'CB: default_1',
 'User: Not with the new variant we won’t ',
 'CB: mutation_1',
 'User: The the vaccine was rushed, how can we trust it',
 'CB: fast_dev_1',
 'User: The clinical trials could have false information ',
 'CB: default_2',
 'User: Taking the vaccine, does not reduce the risk as it could be ineffective',
 'CB: default_3',
 'User: It could result in getting more ill',
 'CB: get_covid_1',
 'User: I don’t believe that is the case',
 'User: The vaccines cant guarantee protection ',
 'CB: default_1',
 'User: Thats what boris said last year and it hasnt worked',
 'CB: default_2',
 'User: What about the side effects?',
 'CB: short_term_1',
 'User: I dont think the vaccine has been trialled enough',
 'CB: default_3',
 'User: I worry the long term effects will be worse',
 'CB: long_term_1',
 'User: Its not guaranteed i will suffer from covid 19 badly though',
 "User: I'm not against vaccines I just don't take medicines I don't feel I need.",
 'CB: default_1',
 "User: In which case it wouldn't be worth me taking the vaccine anyway",
 'CB: default_2',
 "User: I know that, but I'm in good health for my age",
 'CB: default_3',
 "User: I don't worry about my health, and why am I in a position if persuade family and friends if I'm not taking it myself?",
 "User: Because i don't think it has been tested enough.",
 'CB: safety_1',
 'User: I still feel it is unsafe.',
 'CB: default_1',
 "User: I don't believe it will be as simple as that.",
 'CB: default_2',
 "User: I still don't want to have the vaccine.",
 'CB: default_3',
 'User: I am still very concerned that the vaccine is not safe.',
 'CB: safety_2',
 'User: But i think it is very unlikely anyway that i will get Covid.',
 'User: because it was created way too fast compared to any other vaccine',
 'CB: fast_dev_1',
 'User: ok',
 'CB: default_1',
 'User: yes',
 'CB: default_2',
 'User: yes',
 'CB: default_3',
 'User: true',
 "User: I don't fully trust it or deem it necessary for me",
 'CB: default_1',
 'User: Yes but it may not be fully effective',
 'CB: default_2',
 'User: OKay',
 'CB: default_3',
 'User: It may have side effects though',
 'CB: short_term_1',
 "User: This vaccine was made very quickly though, could say it's been rushed",
 'CB: fast_dev_1',
 'User: Okay interesting',
 "User: It's been developed in a hurry",
 'CB: default_1',
 'User: Yes',
 'CB: default_2',
 'User: Ok',
 'CB: default_3',
 'User: Maybe']
